# %%
# インポート
import pandas as pd

# %%
df = pd.read_csv('./csv/lunch_box.csv', sep=',')

# %%
#先頭5個取得
df.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %%
# 最後尾の5行を表示
df.tail()
# Out:
#       datetime   y week  soldout          name   kcal          remarks  \
# 202  2014-9-24  59    水        1   白身魚のマスタード焼き  408.0              NaN
# 203  2014-9-25  50    木        0       牛カルビ焼き肉  394.0              NaN
# 204  2014-9-26  45    金        0      ランチビュッフェ    NaN  スペシャルメニュー（800円）
# 205  2014-9-29  56    月        1      豚肉と玉子の炒め  404.0              NaN
# 206  2014-9-30  40    火        0  鶏肉とカシューナッツ炒め  398.0              NaN
#
#              event  payday weather precipitation  temperature
# 202            NaN     NaN       曇             0         24.8
# 203            NaN     NaN       曇             0         25.4
# 204  キャリアアップ支援セミナー     NaN      晴れ            --         27.1
# 205            NaN     NaN      快晴            --         26.6
# 206            NaN     NaN      快晴            --         28.1

# %%
#207行と12列ある事が分かる
df.shape
# Out:
# (207, 12)

# %%
#インデックスの確認
df.index
# Out:
# RangeIndex(start=0, stop=207, step=1)

# %%
#カラムの確認
df.columns
# Out:
# Index(['datetime', 'y', 'week', 'soldout', 'name', 'kcal', 'remarks', 'event',
#        'payday', 'weather', 'precipitation', 'temperature'],
#       dtype='object')

# %%
#各カラムの型が分かる
df.dtypes
# Out:
# datetime          object
# y                  int64
# week              object
# soldout            int64
# name              object
# kcal             float64
# remarks           object
# event             object
# payday           float64
# weather           object
# precipitation     object
# temperature      float64
# dtype: object

# %%
#名前とカロリーだけに絞って先頭から5つ取得
df[['name', 'kcal']].head()
# Out:
#          name  kcal
# 0    厚切りイカフライ   NaN
# 1     手作りヒレカツ   NaN
# 2  白身魚唐揚げ野菜あん   NaN
# 3      若鶏ピリ辛焼   NaN
# 4    ビッグメンチカツ   NaN

# %%
#行数も指定できる
df[100:106]
# Out:
#       datetime   y week  soldout      name   kcal   remarks event  payday  \
# 100  2014-4-22  78    火        1     マーボ豆腐  382.0       NaN   NaN     NaN
# 101  2014-4-23  63    水        0   手作りひれかつ  340.0       NaN   NaN     NaN
# 102  2014-4-24  56    木        1  鶏の照り焼きマヨ  360.0       NaN   NaN     NaN
# 103  2014-4-25  80    金        0       中華丼    NaN  お楽しみメニュー   NaN     NaN
# 104  2014-4-28  54    月        0  タンドリーチキン  342.0       NaN   NaN     NaN
# 105  2014-4-30  97    水        1  豚味噌メンチカツ  368.0       NaN   NaN     NaN
#
#     weather precipitation  temperature
# 100       曇            --         18.8
# 101      快晴            --         19.4
# 102      晴れ            --         19.9
# 103      晴れ            --         20.8
# 104      晴れ            --         22.7
# 105       雨           0.5         17.5

# %%
#100行目だけピンポイント
df.loc[100]
# Out:
# datetime         2014-4-22
# y                       78
# week                     火
# soldout                  1
# name                 マーボ豆腐
# kcal                   382
# remarks                NaN
# event                  NaN
# payday                 NaN
# weather                  曇
# precipitation           --
# temperature           18.8
# Name: 100, dtype: object

# %%
#取り出す行も列も指定できる カラムのインデックス番号
df.iloc[[10,30,60], [0,2,3]]
# Out:
#      datetime week  soldout
# 10  2013-12-2    月        1
# 30   2014-1-9    木        1
# 60  2014-2-24    月        1

# %%
#j条件を与えられる
df[df['kcal'] > 30].head()
# Out:
#      datetime    y week  soldout          name   kcal remarks event  payday  \
# 28   2014-1-7  131    火        0  カレー入りソーセージカツ  404.0     NaN   NaN     NaN
# 29   2014-1-8  128    水        0        豚肉の生姜焼  462.0     NaN   NaN     NaN
# 30   2014-1-9  129    木        1        鶏チリソース  435.0     NaN   NaN     NaN
# 31  2014-1-10   87    金        0      手作りロースカツ  440.0     NaN   NaN     1.0
# 32  2014-1-14  129    火        1   鶏の照り焼きマスタード  376.0     NaN   NaN     NaN
#
#    weather precipitation  temperature
# 28      快晴            --          7.3
# 29       曇            --          9.8
# 30       曇            --         10.9
# 31      快晴            --          5.1
# 32      晴れ            --          5.8

# %%
#queryを使えば複数の条件で絞れる
df[['name', 'kcal']].query('kcal > 30 and name == "豚肉の生姜焼" ')
# Out:
#       name   kcal
# 29  豚肉の生姜焼  462.0

# %%
#uniqueを使えば例えばどんなデータが入っているか分かる
df['name'].unique()
# Out:
# array(['厚切りイカフライ', '手作りヒレカツ', '白身魚唐揚げ野菜あん', '若鶏ピリ辛焼', 'ビッグメンチカツ', '鶏の唐揚',
#        '豚のスタミナ炒め', 'ボローニャ風カツ', 'ハンバーグ', 'タルタルinソーセージカツ', 'マーボ豆腐',
#        '厚揚げ豚生姜炒め', 'クリームチーズ入りメンチ', '鶏のカッシュナッツ炒め', '手作りロースカツ',
#        'ハンバーグデミソース', 'やわらかロースのサムジョン', '五目御飯', '肉じゃが', 'タンドリーチキン',
#        'カキフライタルタル', '回鍋肉', 'ポーク味噌焼き', '鶏の唐揚げ甘酢あん', 'さっくりメンチカツ',
#        '手ごね風ハンバーグ', '酢豚', 'カレー入りソーセージカツ', '豚肉の生姜焼', '鶏チリソース',
#        '鶏の照り焼きマスタード', 'さんま辛味焼', 'カレイ唐揚げ野菜あんかけ', 'ジューシーメンチカツ', 'サバ焼味噌掛け',
#        '手作りひれかつとカレー', '鶏のレモンペッパー焼orカレー', 'チンジャオロース', '海老フライタルタル',
#        'チーズ入りメンチカツ', '鶏の唐揚げ', 'メダイ照り焼', 'ハンバーグカレーソース', 'さわら焼味噌掛け',
#        '鶏のピリ辛焼き', 'ホタテクリ―ムシチュー', '鶏の唐揚げおろしソース', 'ますのマスタードソース', 'ロース甘味噌焼き',
#        '海老フライとホタテ串カツ', 'ハンバーグ和風きのこソース', '酢豚orカレー', 'ポークハヤシ',
#        '白身魚唐揚げ野菜あんかけ', '手作りひれかつ', 'メンチカツ', 'チキンクリームシチュー', '海老クリーミ―クノーデル',
#        'ビーフカレー', 'カレイ野菜あんかけ', 'チーズ入りハンバーグ', '越冬キャベツのメンチカツ', '鶏の親子煮',
#        '肉団子クリームシチュー', 'キーマカレー', '青椒肉絲', '和風ソースハンバーグ', '青梗菜牛肉炒め',
#        '肉団子のシチュー', 'チキンカレー', 'ビーフトマト煮', 'ポーク生姜焼き', '牛丼風煮', '鶏の味噌漬け焼き',
#        '牛肉筍煮', '鶏の照り焼きマヨ', '中華丼', '豚味噌メンチカツ', 'マーボ茄子', '鶏の天ぷら',
#        '手作りチキンカツ', 'きのこソースハンバーグ', '白身魚唐揚げ野菜餡かけ', 'ポークカレー', '豚肉と茄子のピリ辛炒め',
#        'チーズハンバーグ', 'サーモンのムニエル2色ソース', '牛肉コロッケ', '牛肉すき焼き風', 'いか天ぷら',
#        'ハンバーグケッチャップソース', 'ゴーヤチャンプルー', 'たっぷりベーコンフライ', '牛肉ニンニクの芽炒め',
#        'カレイ唐揚げ野菜餡かけ', 'チャプチェ', '牛すき焼き風', 'ポークソテー韓国ソース', 'ビーフストロガノフ',
#        'アジ唐揚げ南蛮ソース', '炊き込みご飯', '鶏のトマトシチュー', '豚の冷しゃぶ', 'キスと野菜の天ぷら', '牛丼',
#        '鶏の塩から揚げ', 'カレイ唐揚げ夏野菜あん', '白身魚ムニエル', '手作りトンカツ', '和風ハンバーグ',
#        'かじきの甘辛煮', 'チキンのコーンクリーム焼き', 'プルコギ', '鶏のから揚げねぎ塩炒めソース', '豚冷シャブ野菜添え',
#        '白身魚フライ', '豚すき焼き', 'エビフライ', '八宝菜', 'ジャンボチキンカツ', 'ひやしたぬきうどん・炊き込みご飯',
#        '豚肉のマスタード焼き', 'バーベキューチキン', '鶏のから揚げスイートチリソース', '豚肉の生姜焼き',
#        'ハンバーグ（デミきのこバター）', '鶏肉のカレー唐揚', '豚キムチ炒め', 'チキン香草焼きマスタードソース',
#        'サーモンフライ・タルタル', '厚切ハムカツ', '洋食屋さんのメンチカツ', '牛スキヤキ', '豚ロースのピザ風チーズ焼き',
#        'チキン南蛮', 'ロコモコ丼', '白身魚の南部焼き', 'カレイの唐揚げ', '豚肉の胡麻シャブ', 'チキンの辛味噌焼き',
#        'ビーフシチュー', '名古屋味噌カツ', '親子煮', 'チキンステーキ・きのこソース', '鶏肉の山賊焼き',
#        'ぶりレモンペッパー焼き', 'チーズメンチカツ', 'チキンフリカッセ', 'カレイ唐揚げ 甘酢あん', '厚切イカフライ',
#        '筑前煮', '白身魚のマスタード焼き', '牛カルビ焼き肉', 'ランチビュッフェ', '豚肉と玉子の炒め',
#        '鶏肉とカシューナッツ炒め'], dtype=object)

# %%
#全体の個数
len(df)
# Out:
# 207

# %%
#日付の個数
len(df['datetime'].unique())
# Out:
# 207

# %%
#全体の個数と日付の個数が一致しているか　日付に重複が無いか確認できる
len(df) == len(df['datetime'].unique())
# Out:
# True

# %%
#平均や最大値なんかが分かる
df.describe()
# Out:
#                 y     soldout        kcal  payday  temperature
# count  207.000000  207.000000  166.000000    10.0   207.000000
# mean    86.623188    0.449275  404.409639     1.0    19.252174
# std     32.882448    0.498626   29.884641     0.0     8.611365
# min     29.000000    0.000000  315.000000     1.0     1.200000
# 25%     57.000000    0.000000  386.000000     1.0    11.550000
# 50%     78.000000    0.000000  408.500000     1.0    19.800000
# 75%    113.000000    1.000000  426.000000     1.0    26.100000
# max    171.000000    1.000000  462.000000     1.0    34.600000

# %%
#一回しか実行できない　2回目でエラーが出た
df.set_index('datetime', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-7878060a3394> in <module>
# ----> 1 df.set_index('datetime', inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['datetime'] are in the columns"

# %%
df.head()
# Out:
#               y week  soldout        name  kcal remarks event  payday weather  \
# datetime
# 2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN      快晴
# 2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN      快晴
# 2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN      快晴
# 2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN      快晴
# 2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN      快晴
#
#            precipitation  temperature
# datetime
# 2013-11-18            --         19.8
# 2013-11-19            --         17.0
# 2013-11-20            --         15.5
# 2013-11-21            --         15.2
# 2013-11-22            --         16.1

# %%
df.index
# Out:
# Index(['2013-11-18', '2013-11-19', '2013-11-20', '2013-11-21', '2013-11-22',
#        '2013-11-25', '2013-11-26', '2013-11-27', '2013-11-28', '2013-11-29',
#        ...
#        '2014-9-16', '2014-9-17', '2014-9-18', '2014-9-19', '2014-9-22',
#        '2014-9-24', '2014-9-25', '2014-9-26', '2014-9-29', '2014-9-30'],
#       dtype='object', name='datetime', length=207)

# %%
#カラム名ｙをsalesに変更する
df.rename(columns={'y':'sales'}, inplace=True)

# %%
#salesを昇順に表示　ascending=False　にすれば逆
df.sort_values(by='sales', ascending=True).head()
# Out:
#            sales week  soldout          name   kcal remarks event  payday  \
# datetime
# 2014-9-22     29    月        0           筑前煮  395.0     NaN   NaN     NaN
# 2014-8-1      38    金        0       豚肉の生姜焼き  380.0     NaN   NaN     NaN
# 2014-8-29     39    金        0     チキンの辛味噌焼き  398.0     NaN   NaN     NaN
# 2014-9-30     40    火        0  鶏肉とカシューナッツ炒め  398.0     NaN   NaN     NaN
# 2014-8-12     40    火        1        厚切ハムカツ  400.0     NaN   NaN     NaN
#
#           weather precipitation  temperature
# datetime
# 2014-9-22      晴れ            --         25.2
# 2014-8-1       薄曇            --         32.7
# 2014-8-29       曇             0         25.1
# 2014-9-30      快晴            --         28.1
# 2014-8-12       雨             0         29.4

# %%
#複数条件でも並び替えられる
df.sort_values(['sales', 'temperature'], ascending=False).head(10)
# Out:
#             sales week  soldout           name  kcal remarks event  payday  \
# datetime
# 2013-12-5     171    木        0    鶏のカッシュナッツ炒め   NaN     NaN   NaN     NaN
# 2013-12-9     165    月        1     ハンバーグデミソース   NaN     NaN   NaN     NaN
# 2013-12-16    160    月        0      カキフライタルタル   NaN     NaN   NaN     NaN
# 2013-12-11    157    水        0           五目御飯   NaN     NaN   NaN     NaN
# 2013-12-10    155    火        0  やわらかロースのサムジョン   NaN     NaN   NaN     1.0
# 2013-12-3     153    火        1       厚揚げ豚生姜炒め   NaN     NaN   NaN     NaN
# 2013-11-28    151    木        0          ハンバーグ   NaN     NaN   NaN     NaN
# 2013-12-2     151    月        1          マーボ豆腐   NaN     NaN   NaN     NaN
# 2013-12-4     151    水        1   クリームチーズ入りメンチ   NaN     NaN   NaN     NaN
# 2013-12-19    151    木        0        ポーク味噌焼き   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature
# datetime
# 2013-12-5       快晴            --         13.8
# 2013-12-9        曇            --          9.1
# 2013-12-16      快晴            --         11.3
# 2013-12-11       曇            --         11.0
# 2013-12-10       曇           0.5          7.1
# 2013-12-3       快晴            --         13.9
# 2013-11-28      薄曇            --         17.7
# 2013-12-2       快晴            --         13.8
# 2013-12-4       晴れ            --         13.5
# 2013-12-19       雨           0.5          6.8

# %%
# indexであるdatetimeのdtype='object' を dtype='datetime64[ns]' に変更
# object型のままだと正しくsortされない
df.index = pd.to_datetime(df.index, format='%Y-%m-%d')

# %%
# resampleメソッドで、日単位や月単位で簡単に集計できる
df.resample('M').mean() #月単位で平均値を出力
# Out:
#                  sales   soldout        kcal  payday  temperature
# datetime
# 2013-11-30  124.600000  0.500000         NaN     NaN    16.060000
# 2013-12-31  139.722222  0.444444         NaN     1.0    10.844444
# 2014-01-31  115.222222  0.611111  427.555556     1.0     8.716667
# 2014-02-28  107.842105  0.526316  420.947368     1.0     7.815789
# 2014-03-31   89.350000  0.450000  382.157895     1.0    12.505000
# 2014-04-30   85.761905  0.476190  360.000000     1.0    18.176190
# 2014-05-31   74.200000  0.550000  419.111111     1.0    22.505000
# 2014-06-30   67.285714  0.333333  423.315789     1.0    25.409524
# 2014-07-31   61.363636  0.454545  397.200000     1.0    29.350000
# 2014-08-31   61.166667  0.333333  403.187500     1.0    30.227778
# 2014-09-30   55.550000  0.300000  408.611111     1.0    25.935000

# %%
# 簡単にmonth列やday列を作れるようになる
df['month'] = list(pd.Series(df.index).apply(lambda x: x.month))
df['day'] = list(pd.Series(df.index).apply(lambda x: x.day))

df.head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature  month  day
# datetime
# 2013-11-18      快晴            --         19.8     11   18
# 2013-11-19      快晴            --         17.0     11   19
# 2013-11-20      快晴            --         15.5     11   20
# 2013-11-21      快晴            --         15.2     11   21
# 2013-11-22      快晴            --         16.1     11   22

# %%
# cutメソッドでヒストグラムのビン指定的な処理ができる
# 0<day≦10, 10<day≦20, 20<day≦31 それぞれに中旬とかをふる
labels = ['上旬', '中旬', '下旬']
df['period'] =  pd.cut(list(df['day']),bins=[0,10,20,31], labels=labels, right=True)

# %%
df.head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature  month  day period
# datetime
# 2013-11-18      快晴            --         19.8     11   18     中旬
# 2013-11-19      快晴            --         17.0     11   19     中旬
# 2013-11-20      快晴            --         15.5     11   20     中旬
# 2013-11-21      快晴            --         15.2     11   21     下旬
# 2013-11-22      快晴            --         16.1     11   22     下旬

# %%
#True にnullが入ってる
df.isnull()
# Out:
#             sales   week  soldout   name   kcal  remarks  event  payday  \
# datetime
# 2013-11-18  False  False    False  False   True     True   True    True
# 2013-11-19  False  False    False  False   True     True   True    True
# 2013-11-20  False  False    False  False   True     True   True    True
# 2013-11-21  False  False    False  False   True     True   True    True
# 2013-11-22  False  False    False  False   True     True   True    True
# ...           ...    ...      ...    ...    ...      ...    ...     ...
# 2014-09-24  False  False    False  False  False     True   True    True
# 2014-09-25  False  False    False  False  False     True   True    True
# 2014-09-26  False  False    False  False   True    False  False    True
# 2014-09-29  False  False    False  False  False     True   True    True
# 2014-09-30  False  False    False  False  False     True   True    True
#
#             weather  precipitation  temperature  month    day  period
# datetime
# 2013-11-18    False          False        False  False  False   False
# 2013-11-19    False          False        False  False  False   False
# 2013-11-20    False          False        False  False  False   False
# 2013-11-21    False          False        False  False  False   False
# 2013-11-22    False          False        False  False  False   False
# ...             ...            ...          ...    ...    ...     ...
# 2014-09-24    False          False        False  False  False   False
# 2014-09-25    False          False        False  False  False   False
# 2014-09-26    False          False        False  False  False   False
# 2014-09-29    False          False        False  False  False   False
# 2014-09-30    False          False        False  False  False   False
#
# [207 rows x 14 columns]

# %%
#trueを数えてそれぞれにどれだけnullが入っているか調べる
df.isnull().sum()
# Out:
# sales              0
# week               0
# soldout            0
# name               0
# kcal              41
# remarks          186
# event            193
# payday           197
# weather            0
# precipitation      0
# temperature        0
# month              0
# day                0
# period             0
# dtype: int64

# %%
#nullが一つでも含まれている行だけをカウント
df[df.isnull().any(axis=1)].shape
# Out:
# (207, 14)

# %%
df[df.isnull().any(axis=1)].head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#            weather precipitation  temperature  month  day period
# datetime
# 2013-11-18      快晴            --         19.8     11   18     中旬
# 2013-11-19      快晴            --         17.0     11   19     中旬
# 2013-11-20      快晴            --         15.5     11   20     中旬
# 2013-11-21      快晴            --         15.2     11   21     下旬
# 2013-11-22      快晴            --         16.1     11   22     下旬

# %%
# 'payday'列にあるNaNを'0.0'に置き換える
df.fillna(value={'payday': 0.0}, inplace=True)
df.head()
# Out:
#             sales week  soldout        name  kcal remarks event  payday  \
# datetime
# 2013-11-18     90    月        0    厚切りイカフライ   NaN     NaN   NaN     0.0
# 2013-11-19    101    火        1     手作りヒレカツ   NaN     NaN   NaN     0.0
# 2013-11-20    118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     0.0
# 2013-11-21    120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     0.0
# 2013-11-22    130    金        1    ビッグメンチカツ   NaN     NaN   NaN     0.0
#
#            weather precipitation  temperature  month  day period
# datetime
# 2013-11-18      快晴            --         19.8     11   18     中旬
# 2013-11-19      快晴            --         17.0     11   19     中旬
# 2013-11-20      快晴            --         15.5     11   20     中旬
# 2013-11-21      快晴            --         15.2     11   21     下旬
# 2013-11-22      快晴            --         16.1     11   22     下旬

# %%
df.isnull().sum() # 'payday'が0になった
# Out:
# sales              0
# week               0
# soldout            0
# name               0
# kcal              41
# remarks          186
# event            193
# payday             0
# weather            0
# precipitation      0
# temperature        0
# month              0
# day                0
# period             0
# dtype: int64

# %%
# 'kcal'列にNaNがある行を削除する
df.dropna(subset=['kcal'], axis=0, inplace=True)

# %%
#減った
df.shape
# Out:
# (166, 14)

# %%
df.isnull().sum() # kcal'がNaNがなくなって0になっていることがわかる
# Out:
# sales              0
# week               0
# soldout            0
# name               0
# kcal               0
# remarks          158
# event            155
# payday             0
# weather            0
# precipitation      0
# temperature        0
# month              0
# day                0
# period             0
# dtype: int64

# %%
# 'precipitation' 列の '--' を 0に置き換える
df['precipitation'] = df['precipitation'].replace('--', 0)
df.head()
# Out:
#             sales week  soldout          name   kcal remarks event  payday  \
# datetime
# 2014-01-07    131    火        0  カレー入りソーセージカツ  404.0     NaN   NaN     0.0
# 2014-01-08    128    水        0        豚肉の生姜焼  462.0     NaN   NaN     0.0
# 2014-01-09    129    木        1        鶏チリソース  435.0     NaN   NaN     0.0
# 2014-01-10     87    金        0      手作りロースカツ  440.0     NaN   NaN     1.0
# 2014-01-14    129    火        1   鶏の照り焼きマスタード  376.0     NaN   NaN     0.0
#
#            weather precipitation  temperature  month  day period
# datetime
# 2014-01-07      快晴             0          7.3      1    7     上旬
# 2014-01-08       曇             0          9.8      1    8     上旬
# 2014-01-09       曇             0         10.9      1    9     上旬
# 2014-01-10      快晴             0          5.1      1   10     上旬
# 2014-01-14      晴れ             0          5.8      1   14     中旬

# %%
# 'remarks(備考)'をデータから列ごと削除
# df.drop(['remarks'], axis=1, inplace=True)
df.shape
# Out:
# (166, 13)

# %%
# weather列の集計
df['weather'].value_counts()
# Out:
# 曇     44
# 晴れ    41
# 快晴    34
# 薄曇    23
# 雨     22
# 雪      1
# 雷電     1
# Name: weather, dtype: int64

# %%
# groupbyメソッドで、'week'列ごとに'soldout'の数をカウントする
df.groupby(['week'])['soldout'].count()
# Out:
# week
# 月    34
# 木    37
# 水    37
# 火    35
# 金    23
# Name: soldout, dtype: int64

# %%
# groupbyメソッドは複数列に対しても行える
# groupbyメソッドで、'month', 'period'列ごとに'sales'の数を合計する
df.groupby(['month', 'period'])['sales'].sum()
# Out:
# month  period
# 1      上旬         475
#        中旬         581
#        下旬        1018
# 2      上旬         725
#        中旬         715
#        下旬         609
# 3      上旬         614
#        中旬         698
#        下旬         369
# 4      上旬         792
#        中旬         344
#        下旬         457
# 5      上旬         316
#        中旬         406
#        下旬         517
# 6      上旬         467
#        中旬         440
#        下旬         311
# 7      上旬         460
#        中旬         277
#        下旬         406
# 8      上旬         288
#        中旬         250
#        下旬         334
# 9      上旬         468
#        中旬         249
#        下旬         234
# Name: sales, dtype: int64

# %%
# wetherごとにtemperatureの平均値を出す
df.groupby(['weather'])['temperature'].mean()
# Out:
# weather
# 快晴    15.294118
# 晴れ    22.558537
# 曇     19.377273
# 薄曇    23.926087
# 雨     18.813636
# 雪      1.200000
# 雷電    19.000000
# Name: temperature, dtype: float64

# %%
df.isnull().sum()
# Out:
# sales              0
# week               0
# soldout            0
# name               0
# kcal               0
# event            155
# payday             0
# weather            0
# precipitation      0
# temperature        0
# month              0
# day                0
# period             0
# dtype: int64

# %%
df.head()
# Out:
#             sales week  soldout          name   kcal event  payday weather  \
# datetime
# 2014-01-07    131    火        0  カレー入りソーセージカツ  404.0   NaN     0.0      快晴
# 2014-01-08    128    水        0        豚肉の生姜焼  462.0   NaN     0.0       曇
# 2014-01-09    129    木        1        鶏チリソース  435.0   NaN     0.0       曇
# 2014-01-10     87    金        0      手作りロースカツ  440.0   NaN     1.0      快晴
# 2014-01-14    129    火        1   鶏の照り焼きマスタード  376.0   NaN     0.0      晴れ
#
#            precipitation  temperature  month  day period
# datetime
# 2014-01-07             0          7.3      1    7     上旬
# 2014-01-08             0          9.8      1    8     上旬
# 2014-01-09             0         10.9      1    9     上旬
# 2014-01-10             0          5.1      1   10     上旬
# 2014-01-14             0          5.8      1   14     中旬

# %%
import matplotlib.pyplot as plt

# おまじない: 以下を実行するとプロットスタイルが変更されていい感じになる
plt.style.use('ggplot')

# %%
# 日本語フォントの設定
from matplotlib.font_manager import FontProperties
font_path = '/Users/ysdyt/Downloads/TakaoPGothic.ttf'  #DLしたフォントのパスを指定
font_prop = FontProperties(fname=font_path)

# %%
#折れ線グラフ
df['sales'].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
#ヒストグラム
df.plot(kind='hist', y='sales' , bins=10, figsize=(16,4), alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# 頻度的には、
# - 日別で60個くらい売れている日が多いらしい
# - 最大で140個くらい売れている日もあることがわかる　など

# %%
# 散布図
df.plot(kind='scatter', x='kcal', y='sales')
# Out:
# <AxesSubplot:xlabel='kcal', ylabel='sales'>

# %% [markdown]
# 「売上個数」と「カロリー」には相関がなさそう　など
